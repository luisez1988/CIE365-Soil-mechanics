# %% [markdown]
# # Exercises

# %% [markdown]
# ## Example 2.4

# %%
import pandas as pd
from frake import GraphFunctions as GF
import matplotlib.pyplot as plt
import numpy as np
from frake import FileFunctions as FF

# %%
D=[4.75, 2, 0.85, 0.425, 0.25, 0.15, 0.106, 0.075, 0.075]
W=[12.5, 233.67, 144.13, 75.75, 25.47, 10.14, 5.5, 1.7, 1]
Wt=sum(W) #Total weight
Wt
# Out:
# 509.85999999999996

# %%
GSD={'d': D, 'W':W}
GSD=pd.DataFrame(data=GSD)
GSD['R']=1.0
GSD['P']=1.0
for i in range(len(GSD['d'])):
    if (i>0):
        GSD['R'][i]=GSD['R'][i-1]+(GSD['W'][i]*100/Wt)
    else:
        GSD['R'][i]=GSD['W'][i]*100/Wt
GSD['P']=100-GSD['R']
GSD=[GSD]
GSD
# Out:
# [       d       W           R             P
#  0  4.750   12.50    2.451653  9.754835e+01
#  1  2.000  233.67   48.281881  5.171812e+01
#  2  0.850  144.13   76.550426  2.344957e+01
#  3  0.425   75.75   91.407445  8.592555e+00
#  4  0.250   25.47   96.402934  3.597066e+00
#  5  0.150   10.14   98.391715  1.608285e+00
#  6  0.106    5.50   99.470443  5.295571e-01
#  7  0.075    1.70   99.803868  1.961323e-01
#  8  0.075    1.00  100.000000 -1.421085e-14]

# %%
lims=[[0.001, 100],[0,100],1,0,1 ]
GF.PlotAll(GSD, ['1'], 'd', 'P', legendMode=False, hold=1, xlabel=r'Particle diameter ($d$) [mm]',\
          ylabel=r'Percentage finer', xsize=5, ysize=3, lims=lims, linewith=2)
plt.xscale('log')
plt.grid(True)
plt.grid(b=True, which='minor', linestyle='--')
plt.savefig('GSD.svg')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\frake\GraphFunctions.py:73: MatplotlibDeprecationWarning: Support for setting the 'text.latex.preamble' or 'pgf.preamble' rcParam to a list of strings is deprecated since 3.3 and will be removed two minor releases later; set it to a single string instead.
#   plt.rcParams['text.latex.preamble'] = [r'\usepackage{bm}']

# %% [markdown]
# ## Example 2.5

# %%
D=[4.75, 2, 0.85, 0.425, 0.25, 0.15, 0.106, 0.075, 0.075]
W=[0, 12.12, 25.36, 32.15, 33.14, 33.78, 47.56, 50.14, 100.25]
Wt=sum(W) #Total weight
GSD={'d': D, 'W':W}
GSD=pd.DataFrame(data=GSD)
GSD['R']=1.0
GSD['P']=1.0
for i in range(len(GSD['d'])):
    if (i>0):
        GSD['R'][i]=GSD['R'][i-1]+(GSD['W'][i]*100/Wt)
    else:
        GSD['R'][i]=GSD['W'][i]*100/Wt
GSD['P']=100-GSD['R']
GSD=[GSD]
GSD
# Out:
# [       d       W           R           P
#  0  4.750    0.00    0.000000  100.000000
#  1  2.000   12.12    3.623318   96.376682
#  2  0.850   25.36   11.204783   88.795217
#  3  0.425   32.15   20.816143   79.183857
#  4  0.250   33.14   30.723468   69.276532
#  5  0.150   33.78   40.822123   59.177877
#  6  0.106   47.56   55.040359   44.959641
#  7  0.075   50.14   70.029895   29.970105
#  8  0.075  100.25  100.000000    0.000000]

# %%
D=[0.066, 0.045, 0.036, 0.025, 0.015, 0.011, 0.007, 0.005, 0.004, 0.003, 0.0018, 0.0012]
P=[84.5, 74.3, 68.3, 58.2, 48.4, 42.3, 34.6, 28.1, 24.3, 20.1, 16.2, 12.3]
GSD1={'d': D, 'P':P}
GSD1=pd.DataFrame(data=GSD1)
GSD.append(GSD1)

# %%
lims=[[0.001, 100],[0,100],1,0,1 ]
IDs=[r'Sieve analysis',r'Hydrometer']
GF.PlotAll(GSD, IDs, 'd', 'P', hold=1, xlabel=r'Particle diameter ($d$) [mm]',\
          ylabel=r'Percentage finer', xsize=7, ysize=4, lims=lims, linewith=2)
plt.xscale('log')
plt.grid(True)
plt.grid(b=True, which='minor', linestyle='--')
plt.savefig('combinedGSD.svg')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\frake\GraphFunctions.py:73: MatplotlibDeprecationWarning: Support for setting the 'text.latex.preamble' or 'pgf.preamble' rcParam to a list of strings is deprecated since 3.3 and will be removed two minor releases later; set it to a single string instead.
#   plt.rcParams['text.latex.preamble'] = [r'\usepackage{bm}']

# %%
GSD2=GSD1.copy()
# GSD2['P']=GSD1['P']*GSD[0]['P'][7]/100
GSD.append(GSD2)
GSD[1]
# Out:
#          d     P
# 0   0.0660  84.5
# 1   0.0450  74.3
# 2   0.0360  68.3
# 3   0.0250  58.2
# 4   0.0150  48.4
# 5   0.0110  42.3
# 6   0.0070  34.6
# 7   0.0050  28.1
# 8   0.0040  24.3
# 9   0.0030  20.1
# 10  0.0018  16.2
# 11  0.0012  12.3

# %%
type(GSD2)
# Out:
# pandas.core.frame.DataFrame

# %%
GSD[2]['P']=GSD[2]['P']*GSD[0]['P'][7]/100

# %%
GSD[1]
# Out:
#          d     P
# 0   0.0660  84.5
# 1   0.0450  74.3
# 2   0.0360  68.3
# 3   0.0250  58.2
# 4   0.0150  48.4
# 5   0.0110  42.3
# 6   0.0070  34.6
# 7   0.0050  28.1
# 8   0.0040  24.3
# 9   0.0030  20.1
# 10  0.0018  16.2
# 11  0.0012  12.3

# %%
lims=[[0.001, 100],[0,100],1,0,1 ]
IDs=[r'Sieve analysis',r'Hydrometer unc', r'Hydrometer corr.']
GF.PlotAll(GSD, IDs, 'd', 'P', hold=1, xlabel=r'Particle diameter ($d$) [mm]',\
          ylabel=r'Percentage finer', xsize=7, ysize=4, lims=lims, linewith=2)
plt.xscale('log')
plt.grid(True)
plt.grid(b=True, which='minor', linestyle='--')
plt.savefig('combinedGSD_2.svg')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\frake\GraphFunctions.py:73: MatplotlibDeprecationWarning: Support for setting the 'text.latex.preamble' or 'pgf.preamble' rcParam to a list of strings is deprecated since 3.3 and will be removed two minor releases later; set it to a single string instead.
#   plt.rcParams['text.latex.preamble'] = [r'\usepackage{bm}']

# %% [markdown]
# # HM2

# %%
Wc=np.array([45.3, 43, 45.2, 45.6])
Ww=np.array([57.1, 59.8, 61.7, 58.4])
Wd=np.array([54.4,56, 57.9, 55.3])
N=np.array([28, 31, 22, 18])

# %%
w=(Ww-Wd)*100/(Wd-Wc)
Data={'w':w, 'N':N}
Data=pd.DataFrame(data=Data)
Data=[Data]

# %%
GF.PlotAll(Data,['1'], 'N', 'w', mode='*', legendMode=False, xlabel=r'Blow count ($N$)', ylabel=r'Water content ($w$) [\%]',\
          hold=1)
x=np.array([17, 31])
y=-0.1838*x+34.744
plt.plot(x,y,'k')
plt.savefig('P6.svg')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\frake\GraphFunctions.py:73: MatplotlibDeprecationWarning: Support for setting the 'text.latex.preamble' or 'pgf.preamble' rcParam to a list of strings is deprecated since 3.3 and will be removed two minor releases later; set it to a single string instead.
#   plt.rcParams['text.latex.preamble'] = [r'\usepackage{bm}']

# %%
N=np.array([6, 12, 20, 28, 32])
w=np.array([52.5, 47.1, 43.2, 38.6, 37])
Data={'N':N, 'w':w}
Data=pd.DataFrame(data=Data)
Data=[Data]

# %%
GF.PlotAll(Data,['1'], 'N', 'w', mode='*', legendMode=False, xlabel=r'Blow count ($N$)', ylabel=r'Water content ($w$) [\%]',\
          hold=1)
x=np.array([2, 35])
y=-0.5814*x+55.076
plt.plot(x,y,'k')
plt.savefig('P5.svg')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\frake\GraphFunctions.py:73: MatplotlibDeprecationWarning: Support for setting the 'text.latex.preamble' or 'pgf.preamble' rcParam to a list of strings is deprecated since 3.3 and will be removed two minor releases later; set it to a single string instead.
#   plt.rcParams['text.latex.preamble'] = [r'\usepackage{bm}']

# %%
Sieve_Data, _, _=FF.OpenFromFolder()

# %%
Sieve_Data[0].head()
# Out:
#        d    P
# 0  75.00  100
# 1  38.00   70
# 2  19.00   49
# 3   9.50   36
# 4   4.75   27

# %%
Labels=[r'Soil A', r'Soil B', r'Soil C', r'Soil D', r'Soil E', r'Soil F']

# %%
lims=[[0.001, 100],[0,100],1,0,1 ]
GF.PlotAll(Sieve_Data, Labels, 'd', 'P', mode='.-',hold=1, xlabel=r'Particle diameter ($d$) [mm]',\
          ylabel=r'Percentage finer', xsize=7, ysize=4, lims=lims, linewith=2)
plt.xscale('log')
plt.grid(True)
plt.grid(b=True, which='minor', linestyle='--')
plt.savefig('P7.svg')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\frake\GraphFunctions.py:73: MatplotlibDeprecationWarning: Support for setting the 'text.latex.preamble' or 'pgf.preamble' rcParam to a list of strings is deprecated since 3.3 and will be removed two minor releases later; set it to a single string instead.
#   plt.rcParams['text.latex.preamble'] = [r'\usepackage{bm}']

# %%
data_compaction, _, _=FF.OpenFromFolder()

# %%
data_compaction[0].head()
# Out:
#        y     w
# 0  15.96  10.9
# 1  16.08  12.3
# 2  17.07  16.3
# 3  16.75  20.1
# 4  16.16  22.4

# %%
from scipy.interpolate import make_interp_spline, BSpline

# %%
legend_comp=[r'Low energy',  r'Modified', r'Standard']
GF.PlotAll(data_compaction, legend_comp, 'w', 'y', mode='*', hold=1, xsize=4, ysize=3,\
          xlabel=r'Water content ($w$) [\%]', ylabel=r'Dry unit weight ($\gamma_d$) [kN/m$^3$]')

# Fit to data
y_max=[]
for frame in data_compaction:
    xnew= np.linspace(frame['w'].min(), frame['w'].max(), 300)
    spl = make_interp_spline(frame['w'],frame['y'], k=3) 
    y_smooth = spl( xnew)
    y_max.append(max(y_smooth))
    plt.plot(xnew,y_smooth)
    
# Saturation lines
S=[0.7, 0.8, 0.9, 1]
xnew= np.linspace(7, 25, 300)
for s in S:
    y=2.64*9.81/(1+(xnew*2.64/100)/s)
    plt.plot(xnew,y, ':')

plt.grid(b=True, which='major', color='grey', linestyle='-')
plt.grid(b=True, which='minor', color='grey', linestyle='--')
plt.savefig('P8.svg')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\frake\GraphFunctions.py:73: MatplotlibDeprecationWarning: Support for setting the 'text.latex.preamble' or 'pgf.preamble' rcParam to a list of strings is deprecated since 3.3 and will be removed two minor releases later; set it to a single string instead.
#   plt.rcParams['text.latex.preamble'] = [r'\usepackage{bm}']

# %%
y_max
# Out:
# [17.13036635591002, 18.964517905488105, 17.277400085795566]
